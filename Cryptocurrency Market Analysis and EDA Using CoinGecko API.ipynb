# %%
import requests
import pandas as pd
import numpy as np

# API URL
url = "https://api.coingecko.com/api/v3/coins/markets"

# Your API key
api_key = "CG-ikdsyYZQvQrg3cYtn3fReiY6"

# Parameters
params = {
    "vs_currency": "usd",
    "order": "market_cap_desc",
    "per_page": 100,
    "page": 1
}

# Headers
headers = {
    "x-cg-demo-api-key": api_key
}

# Send request
response = requests.get(
    url,
    params=params,
    headers=headers
)

# Check status
print("Status code:", response.status_code)

# Convert JSON to Python data
data = response.json()

# Convert to DataFrame
df = pd.DataFrame(data)

print(df.head())
# Out:
# Status code: 200
#             id symbol      name  \
# 0      bitcoin    btc   Bitcoin
# 1     ethereum    eth  Ethereum
# 2       tether   usdt    Tether
# 3  binancecoin    bnb       BNB
# 4       ripple    xrp       XRP
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...   79984.000000
# 1  https://coin-images.coingecko.com/coins/images...    2502.190000
# 2  https://coin-images.coingecko.com/coins/images...       0.999989
# 3  https://coin-images.coingecko.com/coins/images...     757.930000
# 4  https://coin-images.coingecko.com/coins/images...       1.420000
#
#       market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  1606158213731                1            1606168452022  2.036625e+10
# 1   305371401888                2             305371401888  8.863135e+09
# 2   183389271343                3             188856124393  4.421059e+10
# 3   100928658798                4             100928656327  1.778066e+09
# 4    89196508856                5             142137848515  1.566641e+09
#
#    high_24h  ...  total_supply    max_supply        ath  \
# 0  80147.00  ...  2.008046e+07  2.100000e+07  126080.00
# 1   2521.39  ...  1.220239e+08           NaN    4946.05
# 2      1.00  ...  1.888593e+11           NaN       1.32
# 3    779.70  ...  1.331619e+08  2.000000e+08    1369.99
# 4      1.43  ...  9.998563e+10  1.000000e+11       3.65
#
#    ath_change_percentage                  ath_date        atl  \
# 0              -36.56088  2025-10-06T10:57:42.000Z  67.810000
# 1              -49.41025  2025-08-24T11:21:03.000Z   0.432979
# 2              -24.42047  2018-07-23T16:00:00.000Z   0.572521
# 3              -44.67642  2025-10-13T00:41:24.000Z   0.039818
# 4              -61.01971  2025-07-17T19:40:53.000Z   0.002686
#
#    atl_change_percentage                  atl_date  \
# 0           1.178548e+05  2013-07-05T16:00:00.000Z
# 1           5.778021e+05  2015-10-19T16:00:00.000Z
# 2           7.466419e+01  2015-03-01T16:00:00.000Z
# 3           1.903396e+06  2017-10-18T16:00:00.000Z
# 4           5.281360e+04  2014-05-21T16:00:00.000Z
#
#                                                  roi              last_updated
# 0                                               None  2026-09-06T12:26:20.000Z
# 1  {'times': 40.83155711655745, 'currency': 'btc'...  2026-09-06T12:26:20.000Z
# 2                                               None  2026-09-06T12:26:20.000Z
# 3                                               None  2026-09-06T12:26:20.000Z
# 4                                               None  2026-09-06T12:26:20.000Z
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (100, 26)

# %%
df
# Out:
#                  id symbol            name  \
# 0           bitcoin    btc         Bitcoin
# 1          ethereum    eth        Ethereum
# 2            tether   usdt          Tether
# 3       binancecoin    bnb             BNB
# 4            ripple    xrp             XRP
# ..              ...    ...             ...
# 95   official-trump  trump  Official Trump
# 96          vechain    vet         VeChain
# 97  curve-dao-token    crv       Curve DAO
# 98   flare-networks    flr           Flare
# 99         ether-fi  ethfi        Ether.fi
#
#                                                 image  current_price  \
# 0   https://coin-images.coingecko.com/coins/images...   79984.000000
# 1   https://coin-images.coingecko.com/coins/images...    2502.190000
# 2   https://coin-images.coingecko.com/coins/images...       0.999989
# 3   https://coin-images.coingecko.com/coins/images...     757.930000
# 4   https://coin-images.coingecko.com/coins/images...       1.420000
# ..                                                ...            ...
# 95  https://coin-images.coingecko.com/coins/images...       2.350000
# 96  https://coin-images.coingecko.com/coins/images...       0.007005
# 97  https://coin-images.coingecko.com/coins/images...       0.373983
# 98  https://coin-images.coingecko.com/coins/images...       0.006670
# 99  https://coin-images.coingecko.com/coins/images...       0.589036
#
#        market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0   1606158213731                1            1606168452022  2.036625e+10
# 1    305371401888                2             305371401888  8.863135e+09
# 2    183389271343                3             188856124393  4.421059e+10
# 3    100928658798                4             100928656327  1.778066e+09
# 4     89196508856                5             142137848515  1.566641e+09
# ..            ...              ...                      ...           ...
# 95      616355926               95               2353572656  1.952003e+08
# 96      602526435               96                602526435  7.057682e+06
# 97      581577869               97                903812731  7.586152e+07
# 98      579187755               98                710453884  3.258790e+06
# 99      568660723               99                568660723  5.022879e+07
#
#         high_24h  ...  total_supply    max_supply            ath  \
# 0   80147.000000  ...  2.008046e+07  2.100000e+07  126080.000000
# 1    2521.390000  ...  1.220239e+08           NaN    4946.050000
# 2       1.000000  ...  1.888593e+11           NaN       1.320000
# 3     779.700000  ...  1.331619e+08  2.000000e+08    1369.990000
# 4       1.430000  ...  9.998563e+10  1.000000e+11       3.650000
# ..           ...  ...           ...           ...            ...
# 95      2.420000  ...  1.000000e+09  1.000000e+09      73.430000
# 96      0.007061  ...  8.598504e+10  8.671263e+10       0.280991
# 97      0.390599  ...  2.415903e+09  3.030303e+09      15.370000
# 98      0.006804  ...  1.064953e+11           NaN       0.150073
# 99      0.600615  ...  9.653500e+08  1.000000e+09       8.530000
#
#     ath_change_percentage                  ath_date        atl  \
# 0               -36.56088  2025-10-06T10:57:42.000Z  67.810000
# 1               -49.41025  2025-08-24T11:21:03.000Z   0.432979
# 2               -24.42047  2018-07-23T16:00:00.000Z   0.572521
# 3               -44.67642  2025-10-13T00:41:24.000Z   0.039818
# 4               -61.01971  2025-07-17T19:40:53.000Z   0.002686
# ..                    ...                       ...        ...
# 95              -96.79521  2025-01-19T03:50:34.000Z   1.370000
# 96              -97.50696  2021-04-18T17:08:21.000Z   0.001917
# 97              -97.56713  2020-08-13T16:00:00.000Z   0.170749
# 98              -95.55546  2023-01-09T19:14:05.000Z   0.005860
# 99              -93.09366  2024-03-27T15:14:46.000Z   0.266530
#
#     atl_change_percentage                  atl_date  \
# 0            1.178548e+05  2013-07-05T16:00:00.000Z
# 1            5.778021e+05  2015-10-19T16:00:00.000Z
# 2            7.466419e+01  2015-03-01T16:00:00.000Z
# 3            1.903396e+06  2017-10-18T16:00:00.000Z
# 4            5.281360e+04  2014-05-21T16:00:00.000Z
# ..                    ...                       ...
# 95           7.174392e+01  2026-08-13T18:40:30.000Z
# 96           2.654009e+02  2020-03-12T18:29:59.000Z
# 97           1.190250e+02  2026-06-06T05:03:15.000Z
# 98           1.381516e+01  2026-08-19T10:09:30.000Z
# 99           1.210017e+02  2026-06-05T19:19:15.000Z
#
#                                                   roi  \
# 0                                                None
# 1   {'times': 40.83155711655745, 'currency': 'btc'...
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96  {'times': -0.01937278234173, 'currency': 'eth'...
# 97                                               None
# 98                                               None
# 99                                               None
#
#                 last_updated
# 0   2026-09-06T12:26:20.000Z
# 1   2026-09-06T12:26:20.000Z
# 2   2026-09-06T12:26:20.000Z
# 3   2026-09-06T12:26:20.000Z
# 4   2026-09-06T12:26:20.000Z
# ..                       ...
# 95  2026-09-06T12:26:20.000Z
# 96  2026-09-06T12:26:20.000Z
# 97  2026-09-06T12:26:20.000Z
# 98  2026-09-06T12:26:20.000Z
# 99  2026-09-06T12:26:20.000Z
#
# [100 rows x 26 columns]

# %%
import requests
import pandas as pd

url = "https://api.coingecko.com/api/v3/coins/markets"

api_key = "CG-ikdsyYZQvQrg3cYtn3fReiY6"

headers = {
    "x-cg-demo-api-key": api_key
}

all_data = []

# Get 10 pages × 50 coins = 500 coins
for page in range(1, 11):

    params = {
        "vs_currency": "usd",
        "order": "market_cap_desc",
        "per_page": 50,
        "page": page
    }

    response = requests.get(
        url,
        params=params,
        headers=headers
    )

    print("Page:", page, "Status:", response.status_code)

    data = response.json()

    all_data.extend(data)

# Convert to DataFrame
df = pd.DataFrame(all_data)

print("Total rows:", len(df))
print(df.head())
# Out:
# Page: 1 Status: 200
# Page: 2 Status: 200
# Page: 3 Status: 200
# Page: 4 Status: 200
# Page: 5 Status: 200
# Page: 6 Status: 200
# Page: 7 Status: 200
# Page: 8 Status: 200
# Page: 9 Status: 200
# Page: 10 Status: 200
# Total rows: 500
#             id symbol      name  \
# 0      bitcoin    btc   Bitcoin
# 1     ethereum    eth  Ethereum
# 2       tether   usdt    Tether
# 3  binancecoin    bnb       BNB
# 4       ripple    xrp       XRP
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...   79986.000000
# 1  https://coin-images.coingecko.com/coins/images...    2502.690000
# 2  https://coin-images.coingecko.com/coins/images...       0.999967
# 3  https://coin-images.coingecko.com/coins/images...     757.950000
# 4  https://coin-images.coingecko.com/coins/images...       1.420000
#
#       market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  1606210807060              1.0             1.606221e+12  2.032945e+10
# 1   305405629623              2.0             3.054056e+11  8.856988e+09
# 2   183389288958              3.0             1.888561e+11  4.419437e+10
# 3   100940133246              4.0             1.009401e+11  1.778739e+09
# 4    89224379654              5.0             1.421823e+11  1.572437e+09
#
#    high_24h  ...  total_supply    max_supply        ath  \
# 0  80147.00  ...  2.008046e+07  2.100000e+07  126080.00
# 1   2521.39  ...  1.220239e+08           NaN    4946.05
# 2      1.00  ...  1.888593e+11           NaN       1.32
# 3    779.70  ...  1.331619e+08  2.000000e+08    1369.99
# 4      1.43  ...  9.998563e+10  1.000000e+11       3.65
#
#    ath_change_percentage                  ath_date        atl  \
# 0              -36.55940  2025-10-06T10:57:42.000Z  67.810000
# 1              -49.40017  2025-08-24T11:21:03.000Z   0.432979
# 2              -24.42213  2018-07-23T16:00:00.000Z   0.572521
# 3              -44.67451  2025-10-13T00:41:24.000Z   0.039818
# 4              -61.01705  2025-07-17T19:40:53.000Z   0.002686
#
#    atl_change_percentage                  atl_date  \
# 0           1.178575e+05  2013-07-05T16:00:00.000Z
# 1           5.779171e+05  2015-10-19T16:00:00.000Z
# 2           7.466037e+01  2015-03-01T16:00:00.000Z
# 3           1.903462e+06  2017-10-18T16:00:00.000Z
# 4           5.281722e+04  2014-05-21T16:00:00.000Z
#
#                                                  roi              last_updated
# 0                                               None  2026-09-06T12:25:20.000Z
# 1  {'times': 40.82549613312513, 'currency': 'btc'...  2026-09-06T12:25:20.000Z
# 2                                               None  2026-09-06T12:25:20.000Z
# 3                                               None  2026-09-06T12:25:20.000Z
# 4                                               None  2026-09-06T12:25:20.000Z
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (500, 26)

# %%
df.to_csv("crypto_data.csv",index=False)

# %%
# cleaning crypto data
print("check missing value:",df.isna().sum())
print("-"*50)
# Out:
# check missing value: id                                    0
# symbol                                0
# name                                  0
# image                                 0
# current_price                         0
# market_cap                            0
# market_cap_rank                       2
# fully_diluted_valuation               0
# total_volume                          0
# high_24h                              0
# low_24h                               0
# price_change_24h                     16
# price_change_percentage_24h          16
# market_cap_change_24h                16
# market_cap_change_percentage_24h     16
# circulating_supply                    0
# total_supply                          0
# max_supply                          206
# ath                                   0
# ath_change_percentage                 0
# ath_date                              0
# atl                                   0
# atl_change_percentage                 0
# atl_date                              0
# roi                                 460
# last_updated                          0
# dtype: int64
# --------------------------------------------------

# %%
#check columns
print("columns:",df.columns)
print("-"*50)

# create all columns into title case
df.columns=df.columns.str.title()
print("title:",df.columns)
# Out:
# columns: Index(['id', 'symbol', 'name', 'image', 'current_price', 'market_cap',
#        'market_cap_rank', 'fully_diluted_valuation', 'total_volume',
#        'high_24h', 'low_24h', 'price_change_24h',
#        'price_change_percentage_24h', 'market_cap_change_24h',
#        'market_cap_change_percentage_24h', 'circulating_supply',
#        'total_supply', 'max_supply', 'ath', 'ath_change_percentage',
#        'ath_date', 'atl', 'atl_change_percentage', 'atl_date', 'roi',
#        'last_updated'],
#       dtype='object')
# --------------------------------------------------
# title: Index(['Id', 'Symbol', 'Name', 'Image', 'Current_Price', 'Market_Cap',
#        'Market_Cap_Rank', 'Fully_Diluted_Valuation', 'Total_Volume',
#        'High_24H', 'Low_24H', 'Price_Change_24H',
#        'Price_Change_Percentage_24H', 'Market_Cap_Change_24H',
#        'Market_Cap_Change_Percentage_24H', 'Circulating_Supply',
#        'Total_Supply', 'Max_Supply', 'Ath', 'Ath_Change_Percentage',
#        'Ath_Date', 'Atl', 'Atl_Change_Percentage', 'Atl_Date', 'Roi',
#        'Last_Updated'],
#       dtype='object')

# %%
df.head(2)
# Out:
#          Id Symbol      Name  \
# 0   bitcoin    btc   Bitcoin
# 1  ethereum    eth  Ethereum
#
#                                                Image  Current_Price  \
# 0  https://coin-images.coingecko.com/coins/images...       79986.00
# 1  https://coin-images.coingecko.com/coins/images...        2502.69
#
#       Market_Cap  Market_Cap_Rank  Fully_Diluted_Valuation  Total_Volume  \
# 0  1606210807060              1.0             1.606221e+12  2.032945e+10
# 1   305405629623              2.0             3.054056e+11  8.856988e+09
#
#    High_24H  ...  Total_Supply  Max_Supply        Ath  Ath_Change_Percentage  \
# 0  80147.00  ...  2.008046e+07  21000000.0  126080.00              -36.55940
# 1   2521.39  ...  1.220239e+08         NaN    4946.05              -49.40017
#
#                    Ath_Date        Atl  Atl_Change_Percentage  \
# 0  2025-10-06T10:57:42.000Z  67.810000           117857.54419
# 1  2025-08-24T11:21:03.000Z   0.432979           577917.14359
#
#                    Atl_Date  \
# 0  2013-07-05T16:00:00.000Z
# 1  2015-10-19T16:00:00.000Z
#
#                                                  Roi              Last_Updated
# 0                                               None  2026-09-06T12:25:20.000Z
# 1  {'times': 40.82549613312513, 'currency': 'btc'...  2026-09-06T12:25:20.000Z
#
# [2 rows x 26 columns]

# %%
# check id columns
print("missing value:",df['Id'].isna().sum())
print("-"*50)

# check duplicated
print("duplicated:",df['Id'].duplicated().sum())
print("-"*50)


# create columns value into title case
df['Id']=df['Id'].str.title()
print("df['Id']")
print("-"*50)

#remove space
df['Id']=df['Id'].str.strip()
print("df['Id']")
# Out:
# missing value: 0
# --------------------------------------------------
# duplicated: 0
# --------------------------------------------------
# df['Id']
# --------------------------------------------------
# df['Id']

# %%
#check Symbol columns
# check missing value
print("missing value:",df['Symbol'].isna().sum())
print("-"*50)

# remove space
df['Symbol']=df['Symbol'].str.strip()
print("df['Symbol']")
print("-"*50)

# create upper case
df["Symbol"] = df["Symbol"].astype("string").str.strip().str.upper()
print("df['Symbol']")
print("-"*50)

# check duplicated
print("duplicated:",df["Symbol"].duplicated().sum())

# count duplicated value
print("count duplicated:",df['Symbol'].value_counts()[:20])
# Out:
# missing value: 0
# --------------------------------------------------
# df['Symbol']
# --------------------------------------------------
# df['Symbol']
# --------------------------------------------------
# duplicated: 6
# count duplicated: Symbol
# PC0000023    2
# SAFE         2
# DAI          2
# USDF         2
# M            2
# USDA         2
# BTC          1
# AIOZ         1
# PC0000101    1
# EXOD         1
# COW          1
# ARKM         1
# FXUSD        1
# BULLA        1
# CGUSD        1
# PC0000019    1
# RIF          1
# SN4          1
# TAG          1
# SUPER        1
# Name: count, dtype: Int64

# %%
#check Name columns
# check missing value
print("missing value:",df['Name'].isna().sum())
print("-"*50)

# check duplicated
print("duplicated:",df['Name'].duplicated().sum())
print("-"*50)

#count duplicated
print("count duplicated:",df['Name'].value_counts())
print("-"*50)

# remove
# Out:
# missing value: 0
# --------------------------------------------------
# duplicated: 1
# --------------------------------------------------
# count duplicated: Name
# Tradable Singapore Fintech SSL            2
# TAGGER                                    1
# KAITO                                     1
# Rootstock Infrastructure Framework        1
# Tradable North America PoS Lender SSTN    1
#                                          ..
# USX                                       1
# AINFT                                     1
# Ape and Pepe                              1
# Kinesis Silver                            1
# Loaded Lions                              1
# Name: count, Length: 499, dtype: int64
# --------------------------------------------------

# %%
df.head(1)
# Out:
#         Id Symbol     Name                                              Image  \
# 0  Bitcoin    BTC  Bitcoin  https://coin-images.coingecko.com/coins/images...
#
#    Current_Price     Market_Cap  Market_Cap_Rank  Fully_Diluted_Valuation  \
# 0        79986.0  1606210807060              1.0             1.606221e+12
#
#    Total_Volume  High_24H  ...  Total_Supply  Max_Supply       Ath  \
# 0  2.032945e+10   80147.0  ...    20080456.0  21000000.0  126080.0
#
#    Ath_Change_Percentage                  Ath_Date    Atl  \
# 0               -36.5594  2025-10-06T10:57:42.000Z  67.81
#
#    Atl_Change_Percentage                  Atl_Date   Roi  \
# 0           117857.54419  2013-07-05T16:00:00.000Z  None
#
#                Last_Updated
# 0  2026-09-06T12:25:20.000Z
#
# [1 rows x 26 columns]

# %%
# check Image columns
# check missing value
print("missing value:",df['Image'].isna().sum())
print("-"*50)

#chack duplicated value
print("duplicated:",df['Image'].duplicated().sum())
print("-"*50)

#check unique
print("unique:",df['Image'].unique())
print("-"*50)

#remove space
df['Image']=df['Image'].str.split()
print("df['Image']")
# Out:
# missing value: 0
# --------------------------------------------------
# duplicated: 0
# --------------------------------------------------
# unique: ['https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400'
#  'https://coin-images.coingecko.com/coins/images/279/large/ethereum.png?1696501628'
#  'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661'
#  'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970'
#  'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442'
#  'https://coin-images.coingecko.com/coins/images/6319/large/USDC.png?1769615602'
#  'https://coin-images.coingecko.com/coins/images/4128/large/solana.png?1718769756'
#  'https://coin-images.coingecko.com/coins/images/1094/large/photo_2026-04-13_09-59-16.png?1776048311'
#  'https://coin-images.coingecko.com/coins/images/68480/large/figure.png?1755863954'
#  'https://coin-images.coingecko.com/coins/images/486/large/Brandmark-Yellow_%281%29.png?1785810558'
#  'https://coin-images.coingecko.com/coins/images/50882/large/hyperliquid.jpg?1729431300'
#  'https://coin-images.coingecko.com/coins/images/5/large/dogecoin.png?1696501409'
#  'https://coin-images.coingecko.com/coins/images/69134/large/Rain_logo_1_.png?1762952191'
#  'https://coin-images.coingecko.com/coins/images/69/large/monero_logo.png?1696501460'
#  'https://coin-images.coingecko.com/coins/images/39926/large/usds.webp?1726666683'
#  'https://coin-images.coingecko.com/coins/images/877/large/Chainlink_Logo_500.png?1760023405'
#  'https://coin-images.coingecko.com/coins/images/27045/large/wbt_token.png?1696526096'
#  'https://coin-images.coingecko.com/coins/images/8418/large/leo-token.png?1696508607'
#  'https://coin-images.coingecko.com/coins/images/975/large/cardano.png?1696502090'
#  'https://coin-images.coingecko.com/coins/images/100/large/fmpFRHHQ_400x400.jpg?1735231350'
#  'https://coin-images.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1696501932'
#  'https://coin-images.coingecko.com/coins/images/9956/large/Badge_Dai.png?1696509996'
#  'https://coin-images.coingecko.com/coins/images/12504/large/uniswap-logo.png?1720676669'
#  'https://coin-images.coingecko.com/coins/images/70468/large/Canton-Ticker_%281%29.png?1762826299'
#  'https://coin-images.coingecko.com/coins/images/33613/large/usde.png?1733810059'
#  'https://coin-images.coingecko.com/coins/images/54977/large/USD1_1000x1000_transparent.png?1749297002'
#  'https://coin-images.coingecko.com/coins/images/2/large/litecoin.png?1696501400'
#  'https://coin-images.coingecko.com/coins/images/17980/large/Gram_Circular_Badge.png?1781524778'
#  'https://coin-images.coingecko.com/coins/images/3688/large/hbar.png?1696504364'
#  'https://coin-images.coingecko.com/coins/images/12559/large/Avalanche_Circle_RedWhite_Trans.png?1696512
#  'https://coin-images.coingecko.com/coins/images/11090/large/InjXBNx9_400x400.jpg?1696511031'
#  'https://coin-images.coingecko.com/coins/images/54860/large/bim-fi.jpg?1742179842'
#  'https://coin-images.coingecko.com/coins/images/32439/large/gekko_%281%29.png?1698228341'
#  'https://coin-images.coingecko.com/coins/images/23496/large/Polymesh-symbol.png?1696522706'
#  'https://coin-images.coingecko.com/coins/images/203/large/Verge_Coin_%28native%29_icon_200x200.jpg?1699220755'
#  'https://coin-images.coingecko.com/coins/images/1371/large/aelf-logo.png?1696502429'
#  'https://coin-images.coingecko.com/coins/images/26037/large/Wiki-Logo.png?1696525114'
#  'https://coin-images.coingecko.com/coins/images/102175433/large/DOS.png?1786300290'
#  'https://coin-images.coingecko.com/coins/images/50749/large/FIUDS_200x200px_%281%29.png?1728956878'
#  'https://coin-images.coingecko.com/coins/images/13929/large/avatar-circle-pink.png?1717638991'
#  'https://coin-images.coingecko.com/coins/images/70693/large/us-icon.png?1763129786'
#  'https://coin-images.coingecko.com/coins/images/15279/large/Casper_Monogram_Favicon_White_on_Red_Circle_RGB_200px.png?1749832573'
#  'https://coin-images.coingecko.com/coins/images/5217/large/image_widget_biddfvxd454b1.png?1696505726'
#  'https://coin-images.coingecko.com/coins/images/54291/large/mantis-symbol.png?1739083455'
#  'https://coin-images.coingecko.com/coins/images/70636/large/icon.png?1767003505'
#  'https://coin-images.coingecko.com/coins/images/14051/large/Mask_Network.jpg?1696513776'
#  'https://coin-images.coingecko.com/coins/images/66793/large/tradable.jpg?1750576283'
#  'https://coin-images.coingecko.com/coins/images/71100/large/magma.png?1765796989'
#  'https://coin-images.coingecko.com/coins/images/37869/large/New_Logo_SQD_Icon.png?1720048443'
#  'https://coin-images.coingecko.com/coins/images/67385/large/iusd.jpg?1752628477'
#  'https://coin-images.coingecko.com/coins/images/34608/large/Logomark_200x200.png?1715107868'
#  'https://coin-images.coingecko.com/coins/images/54686/large/_LION_Token_Artwork.png?1741015702']
# --------------------------------------------------
# df['Image']

# %%
# check Current_Price columns
print("missing value:",df['Current_Price'].isna().sum())
print("="*50)

# check duplicated
print("duplicated:",df['Current_Price'].duplicated().sum())
#count duplicated
print("count duplicated:",df['Current_Price'].value_counts())

# check zero value
print("count zero:",(df['Current_Price']==0).sum())
print("="*50)

# check negetive value
print("negative value:",(df['Current_Price'] < 0).sum())
# Out:
# missing value: 0
# ==================================================
# duplicated: 33
# count duplicated: Current_Price
# 1.000000e+00    23
# 1.140000e+00     3
# 1.120000e+00     3
# 1.180000e+00     2
# 1.420000e+00     2
#                 ..
# 3.447610e-01     1
# 4.524980e-01     1
# 9.994530e-01     1
# 2.416060e-07     1
# 1.502830e-03     1
# Name: count, Length: 467, dtype: int64
# count zero: 0
# ==================================================
# negative value: 0

# %%
df.columns
# Out:
# Index(['Id', 'Symbol', 'Name', 'Image', 'Current_Price', 'Market_Cap',
#        'Market_Cap_Rank', 'Fully_Diluted_Valuation', 'Total_Volume',
#        'High_24H', 'Low_24H', 'Price_Change_24H',
#        'Price_Change_Percentage_24H', 'Market_Cap_Change_24H',
#        'Market_Cap_Change_Percentage_24H', 'Circulating_Supply',
#        'Total_Supply', 'Max_Supply', 'Ath', 'Ath_Change_Percentage',
#        'Ath_Date', 'Atl', 'Atl_Change_Percentage', 'Atl_Date', 'Roi',
#        'Last_Updated'],
#       dtype='object')

# %%
df.head(1)
# Out:
#         Id Symbol     Name                                              Image  \
# 0  Bitcoin    BTC  Bitcoin  [https://coin-images.coingecko.com/coins/image...
#
#    Current_Price     Market_Cap  Market_Cap_Rank  Fully_Diluted_Valuation  \
# 0        79986.0  1606210807060              1.0             1.606221e+12
#
#    Total_Volume  High_24H  ...  Total_Supply  Max_Supply       Ath  \
# 0  2.032945e+10   80147.0  ...    20080456.0  21000000.0  126080.0
#
#    Ath_Change_Percentage                  Ath_Date    Atl  \
# 0               -36.5594  2025-10-06T10:57:42.000Z  67.81
#
#    Atl_Change_Percentage                  Atl_Date   Roi  \
# 0           117857.54419  2013-07-05T16:00:00.000Z  None
#
#                Last_Updated
# 0  2026-09-06T12:25:20.000Z
#
# [1 rows x 26 columns]

# %%
# check Market_Cap columns
print("missing value:",df['Market_Cap'].isna().sum())
print("-"*50)

#check duplicated
print("duplicated:",df['Market_Cap'].duplicated().sum())
print("-"*50)

#check zero value
print("zero value:",(df['Market_Cap'] == 0).sum())
print("-"*50)

# check negative value
print("zero value:",(df['Market_Cap'] < 0).sum())
print("-"*50)

#  check  data type
print("data type:",df['Market_Cap'].dtype)
# Out:
# missing value: 0
# --------------------------------------------------
# duplicated: 0
# --------------------------------------------------
# zero value: 0
# --------------------------------------------------
# zero value: 0
# --------------------------------------------------
# data type: int64

# %%
# check Market_Cap_Rank columns
# check missing value
print("missing value:",df['Market_Cap_Rank'].isna().sum())
print("-"*50)

# fill missing value using median
df['Market_Cap_Rank']=df['Market_Cap_Rank'].fillna(df['Market_Cap_Rank'].median())
print("fill missing value:",df['Market_Cap_Rank'])
print("-"*50)

# after fill check missing value
print("missing value:",df['Market_Cap_Rank'].isna().sum())
print("-"*50)

#  check  duplicated value
print("duplicated:",df['Market_Cap_Rank'].duplicated().sum())
print("count duplicated:",df['Market_Cap_Rank'].value_counts())

# check zero value
print("zero value:",(df['Market_Cap_Rank'] == 0).sum())
print("-"*50)

# check negative value
print("negative value:",(df['Market_Cap_Rank'] < 0).sum())
# Out:
# missing value: 2
# --------------------------------------------------
# fill missing value: 0        1.0
# 1        2.0
# 2        3.0
# 3        4.0
# 4        5.0
#        ...
# 495    482.0
# 496    483.0
# 497    484.0
# 498    485.0
# 499    486.0
# Name: Market_Cap_Rank, Length: 500, dtype: float64
# --------------------------------------------------
# missing value: 0
# --------------------------------------------------
# duplicated: 13
# count duplicated: Market_Cap_Rank
# 351.0    2
# 9.0      2
# 386.0    2
# 348.0    2
# 229.0    2
#         ..
# 159.0    1
# 158.0    1
# 157.0    1
# 156.0    1
# 486.0    1
# Name: count, Length: 487, dtype: int64
# zero value: 0
# --------------------------------------------------
# negative value: 0

# %%
df.head(1)
# Out:
#         Id Symbol     Name                                              Image  \
# 0  Bitcoin    BTC  Bitcoin  [https://coin-images.coingecko.com/coins/image...
#
#    Current_Price     Market_Cap  Market_Cap_Rank  Fully_Diluted_Valuation  \
# 0        79986.0  1606210807060              1.0             1.606221e+12
#
#    Total_Volume  High_24H  ...  Total_Supply  Max_Supply       Ath  \
# 0  2.032945e+10   80147.0  ...    20080456.0  21000000.0  126080.0
#
#    Ath_Change_Percentage                  Ath_Date    Atl  \
# 0               -36.5594  2025-10-06T10:57:42.000Z  67.81
#
#    Atl_Change_Percentage                  Atl_Date   Roi  \
# 0           117857.54419  2013-07-05T16:00:00.000Z  None
#
#                Last_Updated
# 0  2026-09-06T12:25:20.000Z
#
# [1 rows x 26 columns]

# %%
# check Fully_Diluted_Valuation columns
print("missing value:",df['Fully_Diluted_Valuation'].isna().sum())
print("-"*50)

# cheeck duplicated
print("duplicated:",df['Fully_Diluted_Valuation'].duplicated().sum())
# count duplicateed
print("count duplicated:",df['Fully_Diluted_Valuation'].value_counts())

# check zero value
print("zero value:",(df['Fully_Diluted_Valuation'] == 0).sum())
print("-"*50)
# convert zero value into nan
df['Fully_Diluted_Valuation']=df['Fully_Diluted_Valuation'].replace(0,np.nan)
print("df['Fully_Diluted_Valuation']")
# Out:
# missing value: 0
# --------------------------------------------------
# duplicated: 1
# count duplicated: Fully_Diluted_Valuation
# 0.000000e+00    2
# 1.606221e+12    1
# 1.715678e+08    1
# 3.117076e+08    1
# 7.547861e+07    1
#                ..
# 2.379042e+08    1
# 2.393120e+08    1
# 2.422788e+08    1
# 2.416075e+08    1
# 1.502956e+08    1
# Name: count, Length: 499, dtype: int64
# zero value: 2
# --------------------------------------------------
# df['Fully_Diluted_Valuation']

# %%
# after coverrt check missing value
print("missing value:",df['Fully_Diluted_Valuation'].isna().sum())
print("-"*50)

# fill them into using median
df['Fully_Diluted_Valuation']=df['Fully_Diluted_Valuation'].fillna(df['Fully_Diluted_Valuation'].median())
print("fill missing value:",df['Fully_Diluted_Valuation'])
# Out:
# missing value: 2
# --------------------------------------------------
# fill missing value: 0      1.606221e+12
# 1      3.054056e+11
# 2      1.888561e+11
# 3      1.009401e+11
# 4      1.421823e+11
#            ...
# 495    2.461298e+08
# 496    4.776895e+07
# 497    4.625038e+07
# 498    6.480976e+07
# 499    1.502956e+08
# Name: Fully_Diluted_Valuation, Length: 500, dtype: float64

# %%
print("missing value:",df['Fully_Diluted_Valuation'].isna().sum())
print("*"*50)
# check negetive value
print("negative value:",(df['Fully_Diluted_Valuation'] < 0).sum())
# Out:
# missing value: 0
# **************************************************
# negative value: 0

# %%
df.columns
# Out:
# Index(['Id', 'Symbol', 'Name', 'Image', 'Current_Price', 'Market_Cap',
#        'Market_Cap_Rank', 'Fully_Diluted_Valuation', 'Total_Volume',
#        'High_24H', 'Low_24H', 'Price_Change_24H',
#        'Price_Change_Percentage_24H', 'Market_Cap_Change_24H',
#        'Market_Cap_Change_Percentage_24H', 'Circulating_Supply',
#        'Total_Supply', 'Max_Supply', 'Ath', 'Ath_Change_Percentage',
#        'Ath_Date', 'Atl', 'Atl_Change_Percentage', 'Atl_Date', 'Roi',
#        'Last_Updated'],
#       dtype='object')

# %%
# check Total_Volume columns
print("missing value:",df['Total_Volume'].isna().sum())
print("-"*50)

# check duplicated
print("check duplicated:",df['Total_Volume'].duplicated().sum())
print("-"*50)

# check data type
print("data type:",df['Total_Volume'].dtype)
print("-"*50)

# check zero value
print("zero value:",(df['Total_Volume'] == 0).sum())
# check thair percentage
print("zero_per:",(df['Total_Volume'] == 0).mean()*100)
print("-"*50)

# covert zero value into nan
df['Total_Volume']=df['Total_Volume'].replace(0,np.nan)
print(df['Total_Volume'])
# Out:
# missing value: 0
# --------------------------------------------------
# check duplicated: 41
# --------------------------------------------------
# data type: float64
# --------------------------------------------------
# zero value: 42
# zero_per: 8.4
# --------------------------------------------------
# 0      2.032945e+10
# 1      8.856988e+09
# 2      4.419437e+10
# 3      1.778739e+09
# 4      1.572437e+09
#            ...
# 495    1.900828e+06
# 496    1.724425e+06
# 497    9.276700e+02
# 498    3.839863e+06
# 499    2.445300e+04
# Name: Total_Volume, Length: 500, dtype: float64

# %%
# after convert nan value check missing value
print("missing value:",df['Total_Volume'].isna().sum())
print("-"*50)

# fill them using median
df['Total_Volume']=df['Total_Volume'].fillna(df['Total_Volume'].median())
print("missing value:",df['Total_Volume'])
# Out:
# missing value: 42
# --------------------------------------------------
# missing value: 0      2.032945e+10
# 1      8.856988e+09
# 2      4.419437e+10
# 3      1.778739e+09
# 4      1.572437e+09
#            ...
# 495    1.900828e+06
# 496    1.724425e+06
# 497    9.276700e+02
# 498    3.839863e+06
# 499    2.445300e+04
# Name: Total_Volume, Length: 500, dtype: float64

# %%
df.columns
# Out:
# Index(['Id', 'Symbol', 'Name', 'Image', 'Current_Price', 'Market_Cap',
#        'Market_Cap_Rank', 'Fully_Diluted_Valuation', 'Total_Volume',
#        'High_24H', 'Low_24H', 'Price_Change_24H',
#        'Price_Change_Percentage_24H', 'Market_Cap_Change_24H',
#        'Market_Cap_Change_Percentage_24H', 'Circulating_Supply',
#        'Total_Supply', 'Max_Supply', 'Ath', 'Ath_Change_Percentage',
#        'Ath_Date', 'Atl', 'Atl_Change_Percentage', 'Atl_Date', 'Roi',
#        'Last_Updated'],
#       dtype='object')

# %%
#check High_24H columns
print("missing value:",df['High_24H'].isna().sum())
print("-"*50)

# check zero value
print("zero value:",(df['High_24H']==0).sum())
print("-"*50)

# convert zero value innto nan 
df['High_24H']=df['High_24H'].replace(0,np.nan)
print(df['High_24H'])

# after covert check missing value
print("missing value:",df['High_24H'].isna().sum())
print("-"*50)

# fill them using meadian
df['High_24H']=df['High_24H'].fillna(df['High_24H'].median())
print(df['High_24H'])
print("-"*50)

# check missing value
print("missing value:",df['High_24H'].isna().sum())
print("-"*50)

# check duplicated
print("check duplicated:",df['High_24H'].duplicated().sum())
# Out:
# missing value: 0
# --------------------------------------------------
# zero value: 10
# --------------------------------------------------
# 0      80147.000000
# 1       2521.390000
# 2          1.000000
# 3        779.700000
# 4          1.430000
#            ...
# 495        0.292096
# 496        0.036415
# 497        1.000000
# 498        0.006576
# 499        0.001517
# Name: High_24H, Length: 500, dtype: float64
# missing value: 10
# --------------------------------------------------
# 0      80147.000000
# 1       2521.390000
# 2          1.000000
# 3        779.700000
# 4          1.430000
#            ...
# 495        0.292096
# 496        0.036415
# 497        1.000000
# 498        0.006576
# 499        0.001517
# Name: High_24H, Length: 500, dtype: float64
# --------------------------------------------------
# missing value: 0
# --------------------------------------------------
# check duplicated: 56

# %%
# check Low_24H columns

# check missing value
print("missing value:",df['Low_24H'].isna().sum())
print("-"*50)

# check data type
print("data type:",df['Low_24H'].dtype)
print("-"*50)

# check zero value
print("zero value:",(df['Low_24H'] == 0).sum())
print("-"*50)

# covert them into nan 
df['Low_24H']=df['Low_24H'].replace(0,np.nan)
print('missing value:',df['Low_24H'])
# Out:
# missing value: 0
# --------------------------------------------------
# data type: float64
# --------------------------------------------------
# zero value: 10
# --------------------------------------------------
# missing value: 0      79586.000000
# 1       2451.620000
# 2          0.999881
# 3        754.740000
# 4          1.410000
#            ...
# 495        0.225349
# 496        0.034887
# 497        0.998726
# 498        0.006431
# 499        0.001470
# Name: Low_24H, Length: 500, dtype: float64

# %%
# after covert  check missing value
print("missing value:",df['Low_24H'].isna().sum())
print("-"*50)

# fill them using median
df['Low_24H']=df['Low_24H'].fillna(df['Low_24H'].median())
print("affter fill missing value",df['Low_24H'])
# Out:
# missing value: 10
# --------------------------------------------------
# affter fill missing value 0      79586.000000
# 1       2451.620000
# 2          0.999881
# 3        754.740000
# 4          1.410000
#            ...
# 495        0.225349
# 496        0.034887
# 497        0.998726
# 498        0.006431
# 499        0.001470
# Name: Low_24H, Length: 500, dtype: float64

# %%
print("missing value:",df['Low_24H'].isna().sum())
print("-"*50)
# check duplicated
print("duplicated:",df['Low_24H'].duplicated().sum())
print("-"*50)

# check data type
print("datatype:",df['Low_24H'].dtype)
# Out:
# missing value: 0
# --------------------------------------------------
# duplicated: 40
# --------------------------------------------------
# datatype: float64

# %%
df.columns
# Out:
# Index(['Id', 'Symbol', 'Name', 'Image', 'Current_Price', 'Market_Cap',
#        'Market_Cap_Rank', 'Fully_Diluted_Valuation', 'Total_Volume',
#        'High_24H', 'Low_24H', 'Price_Change_24H',
#        'Price_Change_Percentage_24H', 'Market_Cap_Change_24H',
#        'Market_Cap_Change_Percentage_24H', 'Circulating_Supply',
#        'Total_Supply', 'Max_Supply', 'Ath', 'Ath_Change_Percentage',
#        'Ath_Date', 'Atl', 'Atl_Change_Percentage', 'Atl_Date', 'Roi',
#        'Last_Updated'],
#       dtype='object')

# %%
# check Price_Change_24H columns
print("missing  value:",df['Price_Change_24H'].isna().sum())
# check zero value
print("zero value:",(df['Price_Change_24H'] == 0).value_counts())
#check nagative value
print("nagetive  value:",(df['Price_Change_24H'] < 0).sum())
print("-"*50)

# filling missing value using median
df['Price_Change_24H']=df['Price_Change_24H'].fillna(df['Price_Change_24H'].median())
print(df['Price_Change_24H'])
print("-"*50)

# check data type 
print("data type:",df['Price_Change_24H'].dtype)
# Out:
# missing  value: 16
# zero value: Price_Change_24H
# False    467
# True      33
# Name: count, dtype: int64
# nagetive  value: 141
# --------------------------------------------------
# 0      320.500000
# 1       47.920000
# 2       -0.000107
# 3        3.410000
# 4        0.016201
#           ...
# 495      0.015668
# 496      0.000125
# 497      0.001353
# 498      0.000035
# 499      0.000028
# Name: Price_Change_24H, Length: 500, dtype: float64
# --------------------------------------------------
# data type: float64

# %%
# check Price_Change_Percentage_24H columns
print("missing value:",df['Price_Change_Percentage_24H'].isna().sum())
print("-"*50)

# fill them using median
df['Price_Change_Percentage_24H']=df['Price_Change_Percentage_24H'].fillna(df['Price_Change_Percentage_24H'].median())
print(df['Price_Change_Percentage_24H'])

print("missing value:",df['Price_Change_Percentage_24H'].isna().sum())
print("-"*50)

# check nagative value
print("nagative value:",(df['Price_Change_Percentage_24H'] < 0).sum())
print("-"*50)

#check data type
print("data type:",df['Price_Change_Percentage_24H'].dtype)
# Out:
# missing value: 16
# --------------------------------------------------
# 0      0.40395
# 1      1.94505
# 2     -0.01041
# 3      0.47163
# 4      1.16012
#         ...
# 495    6.81693
# 496    0.35094
# 497    0.13551
# 498    0.54987
# 499    1.88994
# Name: Price_Change_Percentage_24H, Length: 500, dtype: float64
# missing value: 0
# --------------------------------------------------
# nagative value: 141
# --------------------------------------------------
# data type: float64

# %%
# check Market_Cap_Change_24H columns
print("missinng value:",df['Market_Cap_Change_24H'].isna().sum())
print("-"*50)

# fill them using median
df['Market_Cap_Change_24H']=df['Market_Cap_Change_24H'].fillna(df['Market_Cap_Change_24H'].median())
print(df['Market_Cap_Change_24H'])

# check zero value
print("zero value:",(df['Market_Cap_Change_24H'] == 0).sum())
# check nagative value
print("nagative value:",(df['Market_Cap_Change_24H'] < 0).sum())
print("-"*50)

# check data type
print("data type:",df['Market_Cap_Change_24H'].dtype)
# Out:
# missinng value: 16
# --------------------------------------------------
# 0      6.537168e+09
# 1      5.871785e+09
# 2     -1.679826e+07
# 3      4.629835e+08
# 4      1.051732e+09
#            ...
# 495    3.094618e+06
# 496    1.151770e+05
# 497   -6.562449e+05
# 498    2.684340e+05
# 499    8.590830e+05
# Name: Market_Cap_Change_24H, Length: 500, dtype: float64
# zero value: 32
# nagative value: 137
# --------------------------------------------------
# data type: float64

# %%
df.columns
# Out:
# Index(['Id', 'Symbol', 'Name', 'Image', 'Current_Price', 'Market_Cap',
#        'Market_Cap_Rank', 'Fully_Diluted_Valuation', 'Total_Volume',
#        'High_24H', 'Low_24H', 'Price_Change_24H',
#        'Price_Change_Percentage_24H', 'Market_Cap_Change_24H',
#        'Market_Cap_Change_Percentage_24H', 'Circulating_Supply',
#        'Total_Supply', 'Max_Supply', 'Ath', 'Ath_Change_Percentage',
#        'Ath_Date', 'Atl', 'Atl_Change_Percentage', 'Atl_Date', 'Roi',
#        'Last_Updated'],
#       dtype='object')

# %%
# check Market_Cap_Change_Percentage_24H columns 

print("missing value:",df['Market_Cap_Change_Percentage_24H'].isna().sum())
print("-"*50)

# fill missing value
df['Market_Cap_Change_Percentage_24H']=df['Market_Cap_Change_Percentage_24H'].fillna(df['Market_Cap_Change_Percentage_24H'].median())
print(df['Market_Cap_Change_Percentage_24H'])

# check data type
print("data type:",(df['Market_Cap_Change_Percentage_24H'] == 0).sum())
# Out:
# missing value: 16
# --------------------------------------------------
# 0      0.40866
# 1      1.96031
# 2     -0.00916
# 3      0.46078
# 4      1.19281
#         ...
# 495    7.08636
# 496    0.24948
# 497   -1.39904
# 498    0.58460
# 499    1.89846
# Name: Market_Cap_Change_Percentage_24H, Length: 500, dtype: float64
# data type: 34

# %%
# check Circulating_Supply columns
print("missing value:",df['Circulating_Supply'].isna().sum())
print("-"*50)

# check  data type
print("data type:",df['Circulating_Supply'].dtype)
print("-"*50)

# check zero value
print("zero value:",(df['Circulating_Supply'] == 0).sum())
print("-"*50)

# nagetive value
print("nagetive value:",(df['Circulating_Supply'] < 0).sum())

# Infinite values
print("Infinite value:", np.isinf(df['Circulating_Supply']).sum())
# Out:
# missing value: 0
# --------------------------------------------------
# data type: float64
# --------------------------------------------------
# zero value: 0
# --------------------------------------------------
# nagetive value: 0
# Infinite value: 0

# %%
# check Total_Supply columns
# check datatype
print("data type:",df['Total_Supply'].dtype)
print("-"*50)

# check missing value
print("missing value:",df['Total_Supply'].isna().sum())
print("-"*50)

# check zero value
print("zero value:",(df['Total_Supply'] == 0).sum())
print("-"*50)

#  check nagetive value
print("nagetive value:",(df['Total_Supply'] < 0).sum())

# Infinite values
print("Infinite value:", np.isinf(df['Total_Supply']).sum())

# check unique value
print("unique:",df['Total_Supply'].unique())
# Out:
# data type: float64
# --------------------------------------------------
# missing value: 0
# --------------------------------------------------
# zero value: 0
# --------------------------------------------------
# nagetive value: 0
# Infinite value: 0
# unique: [2.00804560e+07 1.22023858e+08 1.88859329e+11 1.33161861e+08
#  9.99856277e+10 7.45602516e+10 6.33549057e+08 9.49376222e+10
#  2.22906501e+10 1.69176002e+07 9.55307079e+08 1.55802816e+11
#  1.14240854e+12 1.88010700e+07 9.82336230e+09 1.00000000e+09
#  2.93606018e+08 9.85239504e+08 4.50000000e+10 5.00017868e+10
#  2.00853874e+07 4.61038657e+09 8.90460420e+08 3.95391045e+10
#  4.35167510e+09 4.24804590e+09 7.75801606e+07 5.24432421e+09
#  5.00000000e+10 4.63441061e+08 1.00000000e+10 3.26267458e+09
#  5.89496239e+14 1.30558716e+09 2.93579896e+09 2.83228287e+09
#  9.89042441e+10 7.07747089e+05 2.30898805e+09 5.41108823e+09
#  2.40715138e+09 2.10000000e+07 1.92035425e+09 7.80396812e+09
#  1.60000000e+07 6.21931679e+09 4.32503322e+05 1.00000000e+11
#  1.50000000e+10 2.34626651e+10 1.70149872e+09 8.35446237e+11
#  4.20690000e+14 8.98232729e+14 5.56240628e+08 1.47012477e+09
#  9.10920875e+08 1.35545441e+09 1.34408311e+09 1.32000000e+09
#  1.27749911e+09 1.04568748e+09 1.58080489e+08 1.71410471e+10
#  1.07094548e+10 1.18869816e+08 1.42155021e+08 9.11211100e+06
#  1.46124930e+07 8.18874304e+09 7.18027528e+08 6.86243122e+09
#  1.28282433e+07 9.03912445e+09 5.29185592e+08 2.76846793e+10
#  8.09519206e+07 7.17141157e+08 5.33532275e+08 6.91908121e+07
#  3.32454315e+08 6.78300455e+08 6.99000000e+08 1.95709108e+09
#  7.12104762e+08 9.93947027e+09 8.59850412e+10 2.41590286e+09
#  1.06495284e+11 9.65350000e+08 3.80656864e+10 7.67228433e+10
#  1.04554816e+07 7.49995411e+07 3.05455370e+06 3.66660000e+04
#  8.39188802e+07 2.07507363e+06 9.69073134e+08 3.23895399e+10
#  8.69672484e+07 5.84701847e+10 6.50935805e+07 6.80859176e+07
#  4.05380800e+11 7.88856124e+07 5.59186993e+06 7.67220806e+07
#  1.04460000e+07 1.27649810e+09 7.62026396e+07 7.55686340e+07
#  4.20000000e+17 9.97478701e+10 7.51861414e+07 7.50000000e+07
#  8.89897671e+09 5.94939130e+08 9.99999999e+08 7.41111616e+07
#  6.88578338e+07 1.35784439e+06 3.73851733e+08 1.87868246e+07
#  4.96889545e+07 9.99982719e+08 1.63311784e+04 6.46971796e+07
#  1.95394080e+09 2.91514754e+08 5.00000000e+09 7.45775268e+09
#  5.37153036e+05 9.99961859e+08 9.01841822e+04 9.65045993e+07
#  9.99999819e+09 6.90000000e+10 1.09998736e+10 1.03192856e+09
#  1.77619434e+11 7.15938165e+10 6.62353808e+07 6.69620403e+07
#  6.64487456e+07 1.06002408e+07 6.66666666e+08 1.05702157e+09
#  9.99999977e+10 6.53000000e+07 1.02868118e+08 6.52203130e+07
#  2.50000000e+08 1.10076274e+10 3.10882500e+11 5.76715130e+07
#  4.28758864e+05 6.89996596e+10 9.94552574e+08 4.44138109e+09
#  5.58395399e+08 6.10031354e+07 7.88123141e+08 3.70055980e+04
#  3.60137968e+09 1.76923512e+14 3.32000000e+09 9.98384105e+08
#  5.78590410e+07 5.71323810e+07 1.08284694e+09 9.99999099e+08
#  2.37697045e+07 2.05712357e+10 9.98769544e+08 8.80548244e+09
#  2.66443386e+05 9.90960442e+09 2.97451079e+07 2.02013142e+09
#  5.49941613e+07 1.25323976e+09 5.03128597e+10 7.00000000e+08
#  9.00000000e+08 5.39575701e+06 8.76092072e+09 7.83929600e+07
#  1.33248297e+08 1.19663293e+09 5.33900618e+07 1.09602978e+10
#  7.98169426e+08 2.97959666e+09 2.71892858e+08 5.99999997e+08
#  9.79978670e+08 9.96888287e+08 3.99796758e+06 4.20690000e+11
#  2.04800000e+09 2.89266386e+06 5.00142299e+07 9.99841633e+08
#  1.64420903e+10 1.11550000e+10 1.68698990e+09 5.06000000e+07
#  4.08138639e+07 5.01543135e+07 5.01161935e+07 5.00000000e+07
#  1.02799649e+09 1.46434580e+10 1.39307529e+10 9.85222890e+08
#  4.94904091e+07 1.99484176e+09 3.00000000e+07 2.00000000e+14
#  1.31556953e+09 1.65550000e+10 9.99999998e+08 5.35096196e+14
#  3.99766000e+03 6.42292128e+09 1.99016457e+10 6.02548352e+08
#  4.73307489e+07 4.70000000e+07 1.33700000e+09 4.62419208e+07]

# %%
df.columns
# Out:
# Index(['Id', 'Symbol', 'Name', 'Image', 'Current_Price', 'Market_Cap',
#        'Market_Cap_Rank', 'Fully_Diluted_Valuation', 'Total_Volume',
#        'High_24H', 'Low_24H', 'Price_Change_24H',
#        'Price_Change_Percentage_24H', 'Market_Cap_Change_24H',
#        'Market_Cap_Change_Percentage_24H', 'Circulating_Supply',
#        'Total_Supply', 'Max_Supply', 'Ath', 'Ath_Change_Percentage',
#        'Ath_Date', 'Atl', 'Atl_Change_Percentage', 'Atl_Date', 'Roi',
#        'Last_Updated'],
#       dtype='object')

# %%
# check Max_Supply columns

#check data type
print("data type:",df['Max_Supply'].dtype)
print("-"*50)

# check missing value
print("missing value:",df['Max_Supply'].isna().sum())
print("-"*50)

#fill  them using median
df['Max_Supply']=df['Max_Supply'].fillna(df['Max_Supply'].median())
print(df['Max_Supply'])

# check zero value
print("zero value:",(df['Max_Supply']==0).sum())
print("-"*50)

## check nagative value
print("nagative value:",(df['Max_Supply'] < 0).sum())
print("-"*50)

# check duplicated
print("duplicated:",df['Max_Supply'].duplicated().sum())
# Out:
# data type: float64
# --------------------------------------------------
# missing value: 0
# --------------------------------------------------
# 0      2.100000e+07
# 1      1.000000e+09
# 2      1.000000e+09
# 3      2.000000e+08
# 4      1.000000e+11
#            ...
# 495    1.000000e+09
# 496    1.337000e+09
# 497    1.000000e+09
# 498    1.000000e+10
# 499    1.000000e+11
# Name: Max_Supply, Length: 500, dtype: float64
# zero value: 0
# --------------------------------------------------
# nagative value: 0
# --------------------------------------------------
# duplicated: 394

# %%
# check Ath columns

#check data type
print("datatype:",df['Ath'].dtype)
print("-"*50)

#check missing value
print("missing value:",df['Ath'].isna().sum())
print("-"*50)

# check zero value
print("zero value:",(df['Ath']==0).sum())
print("-"*50)

## check nagative value
print("nagative value:",(df['Ath'] < 0).sum())
print("-"*50)
# Out:
# datatype: float64
# --------------------------------------------------
# missing value: 0
# --------------------------------------------------
# zero value: 0
# --------------------------------------------------
# nagative value: 0
# --------------------------------------------------

# %%
# check Ath_Change_Percentage columns
#check data type
print("datatype:",df['Ath_Change_Percentage'].dtype)
print("-"*50)

#check missing value
print("missing value:",df['Ath_Change_Percentage'].isna().sum())
print("-"*50)

# check zero value
print("zero value:",(df['Ath_Change_Percentage']==0).sum())
print("-"*50)

## check nagative value
print("nagative value:",(df['Ath_Change_Percentage'] < 0).sum())
print("-"*50)
# Out:
# datatype: float64
# --------------------------------------------------
# missing value: 0
# --------------------------------------------------
# zero value: 27
# --------------------------------------------------
# nagative value: 472
# --------------------------------------------------

# %%
# check Ath_Date columns

#check data type
print("datatype:",df['Ath_Date'].dtype)
print("-"*50)

#check missing value
print("missing value:",df['Ath_Date'].isna().sum())
print("-"*50)

# check zero value
print("zero value:",(df['Ath_Date']==0).sum())
print("-"*50)

# convert data time  value
df['Ath_Date']=pd.to_datetime(df['Ath_Date'],errors="coerce")
print("unique:",df['Ath_Date'])
print("-"*50)

# remove space 
df['Ath_Date']=df['Ath_Date'].astype(str).str.strip()
print(df['Ath_Date'])
# Out:
# datatype: datetime64[ns, UTC]
# --------------------------------------------------
# missing value: 0
# --------------------------------------------------
# zero value: 0
# --------------------------------------------------
# unique: 0     2025-10-06 10:57:42+00:00
# 1     2025-08-24 11:21:03+00:00
# 2     2018-07-23 16:00:00+00:00
# 3     2025-10-13 00:41:24+00:00
# 4     2025-07-17 19:40:53+00:00
#                  ...
# 495   2026-07-04 00:03:20+00:00
# 496   2025-06-11 10:05:28+00:00
# 497   2026-01-10 20:35:54+00:00
# 498   2024-03-28 15:20:10+00:00
# 499   2025-08-27 18:22:49+00:00
# Name: Ath_Date, Length: 500, dtype: datetime64[ns, UTC]
# --------------------------------------------------
# 0      2025-10-06 10:57:42+00:00
# 1      2025-08-24 11:21:03+00:00
# 2      2018-07-23 16:00:00+00:00
# 3      2025-10-13 00:41:24+00:00
# 4      2025-07-17 19:40:53+00:00
#                  ...
# 495    2026-07-04 00:03:20+00:00
# 496    2025-06-11 10:05:28+00:00
# 497    2026-01-10 20:35:54+00:00
# 498    2024-03-28 15:20:10+00:00
# 499    2025-08-27 18:22:49+00:00
# Name: Ath_Date, Length: 500, dtype: object

# %%
df.columns
# Out:
# Index(['Id', 'Symbol', 'Name', 'Image', 'Current_Price', 'Market_Cap',
#        'Market_Cap_Rank', 'Fully_Diluted_Valuation', 'Total_Volume',
#        'High_24H', 'Low_24H', 'Price_Change_24H',
#        'Price_Change_Percentage_24H', 'Market_Cap_Change_24H',
#        'Market_Cap_Change_Percentage_24H', 'Circulating_Supply',
#        'Total_Supply', 'Max_Supply', 'Ath', 'Ath_Change_Percentage',
#        'Ath_Date', 'Atl', 'Atl_Change_Percentage', 'Atl_Date', 'Roi',
#        'Last_Updated'],
#       dtype='object')

# %%
#check Atl columns
#check data type
print("datatype:",df['Atl'].dtype)
print("-"*50)

#check missing value
print("missing value:",df['Atl'].isna().sum())
print("-"*50)

# check zero value
print("zero value:",(df['Atl']==0).sum())
print("-"*50)

## check nagative value
print("nagative value:",(df['Atl'] < 0).sum())
print("-"*50)
# Out:
# datatype: float64
# --------------------------------------------------
# missing value: 0
# --------------------------------------------------
# zero value: 0
# --------------------------------------------------
# nagative value: 0
# --------------------------------------------------

# %%
# check Atl_Change_Percentage this columns
#check data type
print("datatype:",df['Atl_Change_Percentage'].dtype)
print("-"*50)

#check missing value
print("missing value:",df['Atl_Change_Percentage'].isna().sum())
print("-"*50)

# check zero value
print("zero value:",(df['Atl_Change_Percentage']==0).sum())
print("-"*50)

## check nagative value
print("nagative value:",(df['Atl_Change_Percentage'] < 0).sum())
print("-"*50)
# Out:
# datatype: float64
# --------------------------------------------------
# missing value: 0
# --------------------------------------------------
# zero value: 18
# --------------------------------------------------
# nagative value: 0
# --------------------------------------------------

# %%
# check Atl_Date columns
# Check Atl_Date column

# Check data type
print("datatype:", df['Atl_Date'].dtype)
print("-"*50)

# Check missing value
print("missing value:", df['Atl_Date'].isna().sum())
print("-"*50)

# Check zero value
print("zero value:", (df['Atl_Date'] == 0).sum())
print("-"*50)

# Convert to datetime
df['Atl_Date'] = pd.to_datetime(df['Atl_Date'], errors="coerce")

print("datatype after conversion:", df['Atl_Date'].dtype)
print("-"*50)

# Check missing values after conversion
print("missing after conversion:", df['Atl_Date'].isna().sum())
print("-"*50)

# Check unique dates
print("unique values:", df['Atl_Date'].nunique())
# Out:
# datatype: datetime64[ns, UTC]
# --------------------------------------------------
# missing value: 0
# --------------------------------------------------
# zero value: 0
# --------------------------------------------------
# datatype after conversion: datetime64[ns, UTC]
# --------------------------------------------------
# missing after conversion: 0
# --------------------------------------------------
# unique values: 467

# %%
# check Roi columns
#check data type
print("datatype:",df['Roi'].dtype)
print("-"*50)

#check missing value
print("missing value:",df['Roi'].isna().sum())
print("-"*50)

# check zero value
print("zero value:",(df['Roi']==0).sum())
print("-"*50)

# derop this columns
df.drop('Roi', axis=1, inplace=True)
# Out:
# datatype: object
# --------------------------------------------------
# missing value: 460
# --------------------------------------------------
# zero value: 0
# --------------------------------------------------

# %%
df.columns
# Out:
# Index(['Id', 'Symbol', 'Name', 'Image', 'Current_Price', 'Market_Cap',
#        'Market_Cap_Rank', 'Fully_Diluted_Valuation', 'Total_Volume',
#        'High_24H', 'Low_24H', 'Price_Change_24H',
#        'Price_Change_Percentage_24H', 'Market_Cap_Change_24H',
#        'Market_Cap_Change_Percentage_24H', 'Circulating_Supply',
#        'Total_Supply', 'Max_Supply', 'Ath', 'Ath_Change_Percentage',
#        'Ath_Date', 'Atl', 'Atl_Change_Percentage', 'Atl_Date', 'Last_Updated'],
#       dtype='object')

# %%
# Check Last_Updated column

print("datatype:", df['Last_Updated'].dtype)
print("-"*50)

print("missing value:", df['Last_Updated'].isna().sum())
print("-"*50)

print("zero value:", (df['Last_Updated'] == 0).sum())
print("-"*50)

print("unique values:", df['Last_Updated'].nunique())
# Out:
# datatype: object
# --------------------------------------------------
# missing value: 0
# --------------------------------------------------
# zero value: 0
# --------------------------------------------------
# unique values: 16

# %%
df['Last_Updated']
# Out:
# 0      2026-09-06T12:25:20.000Z
# 1      2026-09-06T12:25:20.000Z
# 2      2026-09-06T12:25:20.000Z
# 3      2026-09-06T12:25:20.000Z
# 4      2026-09-06T12:25:20.000Z
#                  ...
# 495    2026-09-06T12:27:20.000Z
# 496    2026-09-06T12:27:20.000Z
# 497    2026-09-06T12:27:20.000Z
# 498    2026-09-06T12:27:20.000Z
# 499    2026-09-06T12:27:20.000Z
# Name: Last_Updated, Length: 500, dtype: object

# %%
df.to_csv("clean_crypto_data.csv")
